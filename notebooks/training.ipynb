# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from pathlib import Path
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, classification_report, confusion_matrix
)

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

print(f'TensorFlow version : {tf.__version__}')
print(f'Random seed set to  : {SEED}')
# Out:
# TensorFlow version : 2.20.0
# Random seed set to  : 42

# %%
RESULTS_DIR = '/content/drive/MyDrive/ME3/results/'
MODEL_DIR   = '/content/drive/MyDrive/ME3/model/'

os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(MODEL_DIR,   exist_ok=True)
print('Results will be saved to:', RESULTS_DIR)
print('Models  will be saved to:', MODEL_DIR)
# Out:
# Results will be saved to: /content/drive/MyDrive/ME3/results/
# Models  will be saved to: /content/drive/MyDrive/ME3/model/

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f'GPUs available: {len(gpus)}')
    for gpu in gpus:
        print(f' - {gpu}')
else:
    print('No GPU found — training will run on CPU.')
# Out:
# GPUs available: 1
#  - PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# Download the PlantVillage pepper dataset from Kaggle
# Dataset: Plant Disease Classification — contains Pepper__bell__Bacterial_spot
# and Pepper__bell__healthy folders at the top level (no pre-made splits).
import kagglehub
PEPPER_PATH = kagglehub.dataset_download('karagwaanntreasure/plant-disease-detection')
print('Dataset downloaded to:', PEPPER_PATH)
# Out:
# Using Colab cache for faster access to the 'plant-disease-detection' dataset.
# Dataset downloaded to: /kaggle/input/plant-disease-detection

# %%
# Walk the download to find the two pepper class folders
for root, dirs, files in os.walk(PEPPER_PATH):
    depth = root.replace(PEPPER_PATH, '').count(os.sep)
    if depth <= 4:
        name = Path(root).name
        if 'pepper' in name.lower() or depth <= 1:
            print(root)
# Out:
# /kaggle/input/plant-disease-detection
# /kaggle/input/plant-disease-detection/Dataset
# /kaggle/input/plant-disease-detection/Dataset/Pepper__bell___Bacterial_spot
# /kaggle/input/plant-disease-detection/Dataset/Pepper__bell___healthy

# %%
# Locate the two pepper class folders anywhere under PEPPER_PATH
CLASS_KEYWORDS = {
    'healthy':          'Pepper__bell___healthy',
    'bacterial_spot':   'Pepper__bell___Bacterial_spot',
}

found = {}
for dirpath, dirnames, _ in os.walk(PEPPER_PATH):
    base = Path(dirpath).name
    for key, target in CLASS_KEYWORDS.items():
        if base.lower() == target.lower():
            found[key] = Path(dirpath)

healthy_dir       = found.get('healthy')
bacterial_dir     = found.get('bacterial_spot')

print('Healthy dir      :', healthy_dir)
print('Bacterial spot dir:', bacterial_dir)

assert healthy_dir is not None,     'Could not find Pepper__bell__healthy folder'
assert bacterial_dir is not None,   'Could not find Pepper__bell__Bacterial_spot folder'
# Out:
# Healthy dir      : /kaggle/input/plant-disease-detection/Dataset/Pepper__bell___healthy
# Bacterial spot dir: /kaggle/input/plant-disease-detection/Dataset/Pepper__bell___Bacterial_spot

# %%
# Count images in each class folder
def count_images(d):
    if d is None or not Path(d).exists():
        return 0
    exts = ('*.jpg', '*.jpeg', '*.png', '*.JPG', '*.JPEG', '*.PNG')
    return sum(len(list(Path(d).rglob(e))) for e in exts)

n_healthy    = count_images(healthy_dir)
n_bacterial  = count_images(bacterial_dir)
print(f'Healthy images      : {n_healthy}')
print(f'Bacterial spot imgs : {n_bacterial}')
print(f'Total               : {n_healthy + n_bacterial}')
# Out:
# Healthy images      : 1478
# Bacterial spot imgs : 997
# Total               : 2475

# %%
# Build a structured train / val / test split from the two raw class folders.
# Split ratio: 70% train | 15% val | 15% test  (stratified per class)

SPLIT_ROOT  = '/content/pepper_split'
TRAIN_RATIO = 0.70
VAL_RATIO   = 0.15
# TEST_RATIO  = 1 - TRAIN_RATIO - VAL_RATIO  = 0.15

CLASS_MAP = {
    'Healthy':        healthy_dir,
    'Bacterial_Spot': bacterial_dir,
}

def build_split_dirs(split_root, class_map, train_ratio, val_ratio, seed=42):
    """Copy images from raw class folders into train/val/test directory tree."""
    rng = random.Random(seed)

    for split in ('train', 'val', 'test'):
        for cls in class_map:
            os.makedirs(os.path.join(split_root, split, cls), exist_ok=True)

    exts = ('.jpg', '.jpeg', '.png', '.JPG', '.JPEG', '.PNG')

    for cls, src_dir in class_map.items():
        all_imgs = [
            p for p in Path(src_dir).iterdir()
            if p.is_file() and p.suffix in exts
        ]
        rng.shuffle(all_imgs)

        n       = len(all_imgs)
        n_train = int(n * train_ratio)
        n_val   = int(n * val_ratio)

        splits = {
            'train': all_imgs[:n_train],
            'val':   all_imgs[n_train : n_train + n_val],
            'test':  all_imgs[n_train + n_val :],
        }

        for split, imgs in splits.items():
            dst = os.path.join(split_root, split, cls)
            for img_path in imgs:
                shutil.copy2(img_path, os.path.join(dst, img_path.name))
            print(f'  {split:>5} / {cls:<15} : {len(imgs)} images')

# Only build if not already done (avoids re-copying on re-run)
if not Path(SPLIT_ROOT).exists():
    print('Building train/val/test split...')
    build_split_dirs(SPLIT_ROOT, CLASS_MAP, TRAIN_RATIO, VAL_RATIO, seed=SEED)
    print('Done.')
else:
    print('Split already exists at', SPLIT_ROOT)
# Out:
# Building train/val/test split...
#   train / Healthy         : 1034 images
#     val / Healthy         : 221 images
#    test / Healthy         : 223 images
#   train / Bacterial_Spot  : 697 images
#     val / Bacterial_Spot  : 149 images
#    test / Bacterial_Spot  : 151 images
# Done.

# %%
# Confirm split counts
for split in ('train', 'val', 'test'):
    split_path = Path(SPLIT_ROOT) / split
    total = count_images(split_path)
    print(f'{split:>5} : {total} images')
    for cls_dir in sorted(split_path.iterdir()):
        print(f'         {cls_dir.name:<20}: {count_images(cls_dir)}')
# Out:
# train : 1731 images
#          Bacterial_Spot      : 697
#          Healthy             : 1034
#   val : 370 images
#          Bacterial_Spot      : 149
#          Healthy             : 221
#  test : 374 images
#          Bacterial_Spot      : 151
#          Healthy             : 223

# %%
IMAGE_HEIGHT = 224
IMAGE_WIDTH  = 224
BATCH_SIZE   = 32
EPOCHS       = 20
LR           = 1e-4

print(f'Image size   : {IMAGE_HEIGHT} x {IMAGE_WIDTH}')
print(f'Batch size   : {BATCH_SIZE}')
print(f'Max epochs   : {EPOCHS}')
print(f'Learning rate: {LR}')
# Out:
# Image size   : 224 x 224
# Batch size   : 32
# Max epochs   : 20
# Learning rate: 0.0001

# %%
train_dir = Path(SPLIT_ROOT) / 'train'
val_dir   = Path(SPLIT_ROOT) / 'val'
test_dir  = Path(SPLIT_ROOT) / 'test'

train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir, image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE, label_mode='binary',
    seed=SEED, shuffle=True,
)
val_dataset = tf.keras.utils.image_dataset_from_directory(
    val_dir, image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE, label_mode='binary',
    seed=SEED, shuffle=False,
)
test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir, image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE, label_mode='binary',
    seed=SEED, shuffle=False,
)
# Out:
# Found 1731 files belonging to 2 classes.
# Found 370 files belonging to 2 classes.
# Found 374 files belonging to 2 classes.

# %%
class_names = train_dataset.class_names
print(f'Classes: {class_names}')
# Expected: ['Bacterial_Spot', 'Healthy']  (alphabetical order)

if len(class_names) != 2:
    print(f'WARNING: expected 2 classes, found {len(class_names)}: {class_names}')
# Out:
# Classes: ['Bacterial_Spot', 'Healthy']

# %%
# Visualise a sample batch
for images, labels in train_dataset.take(1):
    fixed_images = images.numpy()
    fixed_labels = labels.numpy()

plt.figure(figsize=(12, 8))
for i in range(min(16, len(fixed_images))):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(fixed_images[i].astype('uint8'))
    label_idx = int(fixed_labels[i][0])
    plt.title(class_names[label_idx], fontsize=9)
    plt.axis('off')

plt.suptitle('Pepper Healthy vs Bacterial Spot — Sample Images', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(RESULTS_DIR + 'sample_images.png', dpi=120, bbox_inches='tight')
plt.show()

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_dataset   = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)
test_dataset  = test_dataset.cache().prefetch(buffer_size=AUTOTUNE)

print('Pipeline optimised with cache + shuffle + prefetch.')
# Out:
# Pipeline optimised with cache + shuffle + prefetch.

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.15),
    tf.keras.layers.RandomZoom(0.15),
    tf.keras.layers.RandomContrast(0.15),
], name='data_augmentation')

for images, _ in train_dataset.take(1):
    sample = images[0:1]
    break

fig, axes = plt.subplots(1, 6, figsize=(15, 3))
axes[0].imshow(sample[0].numpy().astype('uint8'))
axes[0].set_title('Original')
axes[0].axis('off')

for i in range(1, 6):
    aug_img = data_augmentation(sample, training=True)[0].numpy().astype('uint8')
    axes[i].imshow(aug_img)
    axes[i].set_title(f'Aug {i}')
    axes[i].axis('off')

plt.suptitle('Data Augmentation Examples', fontsize=11)
plt.tight_layout()
plt.savefig(RESULTS_DIR + 'augmentation_examples.png', dpi=120, bbox_inches='tight')
plt.show()

# %%
def make_callbacks(name, model_dir=MODEL_DIR):
    """Return a fresh set of callbacks for a training run."""
    return [
        tf.keras.callbacks.ModelCheckpoint(
            filepath=os.path.join(model_dir, f'{name}_best.keras'),
            monitor='val_accuracy', save_best_only=True, verbose=1,
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss', patience=6,
            restore_best_weights=True, verbose=1,
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss', factor=0.3,
            patience=3, min_lr=1e-7, verbose=1,
        ),
    ]


def plot_learning_curves(history, title='Learning Curves'):
    """Plot accuracy and loss curves side-by-side."""
    acc       = history.history['accuracy']
    val_acc   = history.history['val_accuracy']
    loss      = history.history['loss']
    val_loss  = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc,     label='Train Accuracy',      linewidth=2)
    plt.plot(epochs_range, val_acc, label='Validation Accuracy', linewidth=2, linestyle='--')
    plt.legend()
    plt.title(f'{title} — Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.grid(alpha=0.3)

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss,     label='Train Loss',      linewidth=2)
    plt.plot(epochs_range, val_loss, label='Validation Loss', linewidth=2, linestyle='--')
    plt.legend()
    plt.title(f'{title} — Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(alpha=0.3)

    plt.tight_layout()
    safe_title = title.lower().replace(' ', '_')
    plt.savefig(RESULTS_DIR + f'{safe_title}_curves.png', dpi=120, bbox_inches='tight')
    plt.show()


def evaluate_model(model, dataset, class_names, title='Model'):
    """Evaluate a binary classification model (sigmoid output, threshold 0.5)."""
    y_true, y_pred, y_prob = [], [], []

    for images, labels in dataset:
        probs = model.predict(images, verbose=0).ravel()
        preds = (probs >= 0.5).astype(int)
        y_prob.append(probs)
        y_pred.append(preds)
        y_true.append(labels.numpy().ravel().astype(int))

    y_true = np.concatenate(y_true)
    y_pred = np.concatenate(y_pred)
    y_prob = np.concatenate(y_prob)

    print(f'\n{title}')
    print(f'Accuracy  : {accuracy_score(y_true, y_pred):.4f}')
    print(f'Precision : {precision_score(y_true, y_pred):.4f}')
    print(f'Recall    : {recall_score(y_true, y_pred):.4f}')
    print(f'F1-Score  : {f1_score(y_true, y_pred):.4f}')
    print('\nClassification Report:')
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(
        cm, cmap='Blues', cbar=False, annot=True, fmt='d',
        xticklabels=class_names, yticklabels=class_names,
        annot_kws={'fontsize': 11, 'fontweight': 'bold'}
    )
    plt.title(f'{title} — Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.tight_layout()
    safe_title = title.lower().replace(' ', '_')
    plt.savefig(RESULTS_DIR + f'{safe_title}_confusion.png', dpi=120, bbox_inches='tight')
    plt.show()

    return accuracy_score(y_true, y_pred)


print('Callbacks and utility functions defined.')
# Out:
# Callbacks and utility functions defined.

# %%
INPUT_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, 3)

def build_transfer_model(input_shape, augmentation):
    base_model = tf.keras.applications.MobileNetV2(
        weights='imagenet',
        input_shape=input_shape,
        include_top=False,
    )
    preprocess_fn = tf.keras.applications.mobilenet_v2.preprocess_input

    # Freeze the base model for the feature-extraction phase
    base_model.trainable = False
    print(f'Base model      : {base_model.name}')
    print(f'Trainable layers: {sum(1 for l in base_model.layers if l.trainable)} / {len(base_model.layers)}')

    inputs  = tf.keras.Input(shape=input_shape)
    x       = augmentation(inputs)
    x       = preprocess_fn(x)                    # scale pixels to [-1, 1]
    x       = base_model(x, training=False)        # frozen inference mode
    x       = tf.keras.layers.GlobalAveragePooling2D()(x)
    x       = tf.keras.layers.Dense(128, activation='relu')(x)
    x       = tf.keras.layers.Dropout(0.3)(x)
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

    return tf.keras.Model(inputs, outputs, name='mobilenetv2_pepper'), base_model


tl_model, base_model = build_transfer_model(INPUT_SHAPE, data_augmentation)
tl_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Base model      : mobilenetv2_1.00_224
# Trainable layers: 0 / 154
# Model: "mobilenetv2_pepper"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,422,081 (9.24 MB)
#  Trainable params: 164,097 (641.00 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
# Phase 1 — Feature Extraction (base frozen)
tl_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
    loss='binary_crossentropy',
    metrics=['accuracy'],
)

tl_history = tl_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    callbacks=make_callbacks('mobilenetv2_pepper_feature_extraction'),
    verbose=1,
)
# Out:
# Epoch 1/20
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6449 - loss: 0.6594
# Epoch 1: val_accuracy improved from None to 0.92703, saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - accuracy: 0.7504 - loss: 0.5164 - val_accuracy: 0.9270 - val_loss: 0.2860 - learning_rate: 1.0000e-04
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8814 - loss: 0.3187
# Epoch 2: val_accuracy improved from 0.92703 to 0.95676, saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9064 - loss: 0.2709 - val_accuracy: 0.9568 - val_loss: 0.1893 - learning_rate: 1.0000e-04
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9336 - loss: 0.1870
# Epoch 3: val_accuracy did not improve from 0.95676
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9330 - loss: 0.1903 - val_accuracy: 0.9514 - val_loss: 0.1746 - learning_rate: 1.0000e-04
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9483 - loss: 0.1597
# Epoch 4: val_accuracy did not improve from 0.95676
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9457 - loss: 0.1586 - val_accuracy: 0.9568 - val_loss: 0.1379 - learning_rate: 1.0000e-04
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9553 - loss: 0.1449
# Epoch 5: val_accuracy improved from 0.95676 to 0.96757, saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9515 - loss: 0.1411 - val_accuracy: 0.9676 - val_loss: 0.1220 - learning_rate: 1.0000e-04
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9452 - loss: 0.1401
# Epoch 6: val_accuracy improved from 0.96757 to 0.97027, saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.9515 - loss: 0.1283 - val_accuracy: 0.9703 - val_loss: 0.1171 - learning_rate: 1.0000e-04
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9627 - loss: 0.1063
# Epoch 7: val_accuracy improved from 0.97027 to 0.97568, saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.9567 - loss: 0.1197 - val_accuracy: 0.9757 - val_loss: 0.1061 - learning_rate: 1.0000e-04
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9622 - loss: 0.1138
# Epoch 8: val_accuracy improved from 0.97568 to 0.97838, saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9584 - loss: 0.1112 - val_accuracy: 0.9784 - val_loss: 0.0933 - learning_rate: 1.0000e-04
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9601 - loss: 0.1100
# Epoch 9: val_accuracy did not improve from 0.97838
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9619 - loss: 0.1035 - val_accuracy: 0.9757 - val_loss: 0.0927 - learning_rate: 1.0000e-04
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9693 - loss: 0.0885
# Epoch 10: val_accuracy did not improve from 0.97838
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9746 - loss: 0.0795 - val_accuracy: 0.9784 - val_loss: 0.0838 - learning_rate: 1.0000e-04
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9704 - loss: 0.0917
# Epoch 11: val_accuracy did not improve from 0.97838
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9682 - loss: 0.0941 - val_accuracy: 0.9784 - val_loss: 0.0812 - learning_rate: 1.0000e-04
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9761 - loss: 0.0696
# Epoch 12: val_accuracy did not improve from 0.97838
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.9757 - loss: 0.0727 - val_accuracy: 0.9784 - val_loss: 0.0763 - learning_rate: 1.0000e-04
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9760 - loss: 0.0793
# Epoch 13: val_accuracy did not improve from 0.97838
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9780 - loss: 0.0770 - val_accuracy: 0.9784 - val_loss: 0.0868 - learning_rate: 1.0000e-04
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9693 - loss: 0.0865
# Epoch 14: val_accuracy improved from 0.97838 to 0.98378, saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_feature_extraction_best.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9728 - loss: 0.0829 - val_accuracy: 0.9838 - val_loss: 0.0729 - learning_rate: 1.0000e-04
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9717 - loss: 0.0841
# Epoch 15: val_accuracy did not improve from 0.98378
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9700 - loss: 0.0859 - val_accuracy: 0.9595 - val_loss: 0.1278 - learning_rate: 1.0000e-04
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9729 - loss: 0.0856
# Epoch 16: val_accuracy did not improve from 0.98378
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9740 - loss: 0.0792 - val_accuracy: 0.9811 - val_loss: 0.0747 - learning_rate: 1.0000e-04
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9733 - loss: 0.0741
# Epoch 17: val_accuracy did not improve from 0.98378
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9780 - loss: 0.0630 - val_accuracy: 0.9784 - val_loss: 0.0819 - learning_rate: 1.0000e-04
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9844 - loss: 0.0557
# Epoch 18: val_accuracy did not improve from 0.98378
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9809 - loss: 0.0623 - val_accuracy: 0.9784 - val_loss: 0.0724 - learning_rate: 3.0000e-05
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9749 - loss: 0.0716
# Epoch 19: val_accuracy did not improve from 0.98378
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9809 - loss: 0.0644 - val_accuracy: 0.9838 - val_loss: 0.0701 - learning_rate: 3.0000e-05
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9768 - loss: 0.0716
# Epoch 20: val_accuracy did not improve from 0.98378
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9821 - loss: 0.0656 - val_accuracy: 0.9784 - val_loss: 0.0746 - learning_rate: 3.0000e-05
# Restoring model weights from the end of the best epoch: 19.

# %%
tl_val_loss, tl_val_acc = tl_model.evaluate(val_dataset, verbose=0)
print(f'MobileNetV2 TL -> val_loss    : {tl_val_loss:.4f}')
print(f'MobileNetV2 TL -> val_accuracy: {tl_val_acc:.4f}')

plot_learning_curves(tl_history, 'MobileNetV2 Transfer Learning — Pepper')
# Out:
# MobileNetV2 TL -> val_loss    : 0.0701
# MobileNetV2 TL -> val_accuracy: 0.9838

# %%
tl_test_acc = evaluate_model(
    tl_model, test_dataset, class_names,
    'MobileNetV2 Transfer — Pepper'
)
# Out:
# MobileNetV2 Transfer — Pepper
# Accuracy  : 0.9920
# Precision : 0.9911
# Recall    : 0.9955
# F1-Score  : 0.9933
#
# Classification Report:
#                 precision    recall  f1-score   support
#
# Bacterial_Spot     0.9933    0.9868    0.9900       151
#        Healthy     0.9911    0.9955    0.9933       223
#
#       accuracy                         0.9920       374
#      macro avg     0.9922    0.9911    0.9917       374
#   weighted avg     0.9920    0.9920    0.9920       374

# %%
# Phase 2 — Fine-Tuning (unfreeze top 30 layers of the base)
base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False

trainable_count = sum(1 for l in base_model.layers if l.trainable)
print(f'Trainable base layers after unfreezing: {trainable_count} / {len(base_model.layers)}')
# Out:
# Trainable base layers after unfreezing: 30 / 154

# %%
FINETUNE_LR = LR / 10   # 1e-5

tl_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=FINETUNE_LR),
    loss='binary_crossentropy',
    metrics=['accuracy'],
)

# %%
ft_history = tl_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=10,
    callbacks=make_callbacks('mobilenetv2_pepper_finetuned'),
    verbose=1,
)
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6265 - loss: 0.9614
# Epoch 1: val_accuracy improved from None to 0.94054, saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_finetuned_best.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/ME3/model/mobilenetv2_pepper_finetuned_best.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 17s 122ms/step - accuracy: 0.7493 - loss: 0.6075 - val_accuracy: 0.9405 - val_loss: 0.1464 - learning_rate: 1.0000e-05
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9214 - loss: 0.1845
# Epoch 2: val_accuracy did not improve from 0.94054
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.9474 - loss: 0.1359 - val_accuracy: 0.9324 - val_loss: 0.1731 - learning_rate: 1.0000e-05
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9674 - loss: 0.0895
# Epoch 3: val_accuracy did not improve from 0.94054
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.9659 - loss: 0.0918 - val_accuracy: 0.9351 - val_loss: 0.1837 - learning_rate: 1.0000e-05
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9663 - loss: 0.0858
# Epoch 4: val_accuracy did not improve from 0.94054
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.9717 - loss: 0.0764 - val_accuracy: 0.9189 - val_loss: 0.2136 - learning_rate: 1.0000e-05
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9715 - loss: 0.0780
# Epoch 5: val_accuracy did not improve from 0.94054
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.9728 - loss: 0.0723 - val_accuracy: 0.9270 - val_loss: 0.2057 - learning_rate: 3.0000e-06
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9694 - loss: 0.0860
# Epoch 6: val_accuracy did not improve from 0.94054
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.9717 - loss: 0.0724 - val_accuracy: 0.9297 - val_loss: 0.1876 - learning_rate: 3.0000e-06
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9735 - loss: 0.0658
# Epoch 7: val_accuracy did not improve from 0.94054
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 8.999999636216671e-07.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.9728 - loss: 0.0696 - val_accuracy: 0.9324 - val_loss: 0.1863 - learning_rate: 3.0000e-06
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
plot_learning_curves(ft_history, 'MobileNetV2 Fine-Tuned — Pepper')

ft_test_acc = evaluate_model(
    tl_model, test_dataset, class_names,
    'MobileNetV2 Fine-Tuned — Pepper'
)

print('\n--- Summary ---')
print(f'Feature-extraction test accuracy : {tl_test_acc:.4f}')
print(f'Fine-tuned         test accuracy : {ft_test_acc:.4f}')
# Out:
# MobileNetV2 Fine-Tuned — Pepper
# Accuracy  : 0.9305
# Precision : 0.8956
# Recall    : 1.0000
# F1-Score  : 0.9449
#
# Classification Report:
#                 precision    recall  f1-score   support
#
# Bacterial_Spot     1.0000    0.8278    0.9058       151
#        Healthy     0.8956    1.0000    0.9449       223
#
#       accuracy                         0.9305       374
#      macro avg     0.9478    0.9139    0.9254       374
#   weighted avg     0.9377    0.9305    0.9291       374
# --- Summary ---
# Feature-extraction test accuracy : 0.9920
# Fine-tuned         test accuracy : 0.9305

# %%
def predict_image(img_path, model, class_names, image_size=(IMAGE_HEIGHT, IMAGE_WIDTH)):
    """Load an image file and classify it with the trained model."""
    img       = tf.keras.utils.load_img(img_path, target_size=image_size)
    img_array = tf.keras.utils.img_to_array(img)   # [0, 255] float32
    img_array = np.expand_dims(img_array, axis=0)   # (1, H, W, 3)

    plt.figure(figsize=(3, 3))
    plt.imshow(img)
    plt.axis('off')
    plt.title('Input Image')
    plt.show()

    prob       = model.predict(img_array, verbose=0)[0][0]
    label      = class_names[int(prob >= 0.5)]
    confidence = prob if prob >= 0.5 else 1 - prob
    print(f'Prediction : {label}')
    print(f'Confidence : {confidence:.4f}')


print('predict_image() utility defined.')
print('Usage: predict_image("/path/to/leaf.jpg", tl_model, class_names)')
# Out:
# predict_image() utility defined.
# Usage: predict_image("/path/to/leaf.jpg", tl_model, class_names)

# %%
# Save the final fine-tuned model to Google Drive
FINAL_MODEL_PATH = '/content/drive/MyDrive/ME3/model/pepper_model.keras'
tl_model.save(FINAL_MODEL_PATH)

print('Model saved:')
print(f'  {FINAL_MODEL_PATH}')
print(f'  Final test accuracy: {ft_test_acc:.4f}')
# Out:
# Model saved:
#   /content/drive/MyDrive/ME3/model/pepper_model.keras
#   Final test accuracy: 0.9305

# %%
# ── Generate class_stats.npz for OOD Layer 2 ─────────────────────────────────────────────
# Run this cell ONCE after training.
# We reload val images directly from disk (no augmentation pipeline) so the
# per-class feature statistics are clean and stable — matching what app.py
# sees at inference time.

import numpy as np
import keras

CLASS_STATS_PATH = FINAL_MODEL_PATH.replace(FINAL_MODEL_PATH.split('/')[-1], 'class_stats.npz')

# Load the saved model
saved_model = keras.models.load_model(FINAL_MODEL_PATH)
print('Model loaded from:', FINAL_MODEL_PATH)

# Build feature extractor: model.input → GlobalAveragePooling2D
gap_layer = next(
    l for l in reversed(saved_model.layers)
    if isinstance(l, keras.layers.GlobalAveragePooling2D)
)
feature_extractor = keras.Model(
    inputs=saved_model.input,
    outputs=gap_layer.output,
    name='feature_extractor',
)
print(f'Feature extractor output shape: {feature_extractor.output_shape}')

# Reload val set FRESH from disk (no cache, no augmentation)
# This ensures features match exactly what app.py computes at inference time.
val_dataset_clean = tf.keras.utils.image_dataset_from_directory(
    val_dir,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE,
    label_mode='binary',
    seed=SEED,
    shuffle=False,
)

# Collect features and labels
all_features, all_labels = [], []
for imgs, lbls in val_dataset_clean:
    feats = feature_extractor(imgs, training=False).numpy()
    all_features.append(feats)
    all_labels.append(lbls.numpy().flatten())

all_features = np.concatenate(all_features, axis=0)  # (N, 1280)
all_labels   = np.concatenate(all_labels,   axis=0)  # (N,)
print(f'Collected {len(all_features)} val samples, feature dim={all_features.shape[1]}')

# Compute per-class mean and std
class_means, class_stds = [], []
for idx, name in enumerate(class_names):
    mask        = all_labels == idx
    class_feats = all_features[mask]
    class_means.append(class_feats.mean(axis=0))
    class_stds.append(class_feats.std(axis=0) + 1e-8)  # avoid div-by-zero
    print(f'  {name}: {mask.sum()} samples')

class_means = np.array(class_means)  # (n_classes, 1280)
class_stds  = np.array(class_stds)   # (n_classes, 1280)

# Save to Drive
np.savez(CLASS_STATS_PATH, means=class_means, stds=class_stds, class_names=class_names)
print(f'\nclass_stats.npz saved to: {CLASS_STATS_PATH}')
print('OOD Layer 2 is now enabled in the Streamlit app.')
# Out:
# Model loaded from: /content/drive/MyDrive/ME3/model/pepper_model.keras
# Feature extractor output shape: (None, 1280)
# Collected 370 val samples, feature dim=1280
#   Bacterial_Spot: 149 samples
#   Healthy: 221 samples
#
# class_stats.npz saved to: /content/drive/MyDrive/ME3/model/class_stats.npz
# OOD Layer 2 is now enabled in the Streamlit app.
